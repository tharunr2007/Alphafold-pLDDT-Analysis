# %% [markdown]
# This Python script compares PLDDT (per-residue confidence) values from PDB files located in two directories (folder1 and folder2). The script performs the following steps:Filename Matching:
#
# Extracts a specific string (characters 6–10) from filenames in both directories to identify corresponding files for comparison.
# PLDDT Extraction:
#
# Reads PLDDT values stored in the B-factor field of PDB files using the Bio.PDB module.
# Histogram Comparison:
#
# Plots histograms of PLDDT values for the corresponding files from the two directories, overlaying the data for comparison.
# Output Graphs:
#
# Saves the generated histograms as PNG files in a specified output_folder.

# %%
import os
import matplotlib.pyplot as plt
from Bio.PDB import PDBParser

# Define the two directories
folder1 = r"/home/nathan/Alphafold-pLDDT-Analysis/AF Structures/S.Cerevisiae/AF 2"
folder2 = r"/home/nathan/Alphafold-pLDDT-Analysis/AF Structures/S.Cerevisiae/AF 3"
output_folder = r"/home/nathan/Alphafold-pLDDT-Analysis/AF2_AF3_Comparison/E.Coli"  # Output directory for graphs

# Function to extract relevant part of filename (assuming the important string is 6-10 characters long)
def extract_relevant_string(filename):
    return filename[6:10].lower()  # Lowercase for case insensitivity

# Function to load PLDDT values from a PDB file
def load_plddt_values_from_pdb(filepath):
    p = PDBParser()
    structure = p.get_structure('PDB_structure', filepath)

    # Assuming PLDDT values are stored in the B-factor field of the PDB file
    plddt_values = []
    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    plddt_values.append(atom.bfactor)  # B-factor (PLDDT score)

    return plddt_values

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Get list of files in both directories
files1 = os.listdir(folder1)
files2 = os.listdir(folder2)

# Create a dictionary to store PLDDT values for comparison
plddt_data = {}

# Compare files between the two directories based on the relevant string in filenames
for file1 in files1:
    relevant_str1 = extract_relevant_string(file1)
    for file2 in files2:
        relevant_str2 = extract_relevant_string(file2)
        if relevant_str1 == relevant_str2:
            # Load PLDDT values for both files
            filepath1 = os.path.join(folder1, file1)
            filepath2 = os.path.join(folder2, file2)
            try:
                plddt1 = load_plddt_values_from_pdb(filepath1)
                plddt2 = load_plddt_values_from_pdb(filepath2)

                # Store the values in a dictionary for histogram plotting
                plddt_data[relevant_str1] = (plddt1, plddt2)
            except Exception as e:
                print(f"Error processing files {file1} and {file2}: {e}")
            break  # Stop after finding the match

# Plot histograms of PLDDT values and save the graphs
for key, (plddt1, plddt2) in plddt_data.items():
    plt.figure(figsize=(5, 4))
    plt.hist(plddt1, bins=50, alpha=0.5, label='AF 3 Prediction')
    plt.hist(plddt2, bins=50, alpha=0.5, label='AF 2 Prediction')
    plt.title('Ecoli Protein pLDDT Distribution by Alphafold Model')
    plt.xlabel('PLDDT Value')
    plt.ylabel('Frequency')
    plt.legend(loc='upper right')

    # Save the plot to the output folder
    output_path = os.path.join(output_folder, f'Ecoli{key}.png')
    plt.savefig(output_path)
    plt.close()  # Close the plot to avoid displaying it interactively

# %%
import os
import matplotlib.pyplot as plt
from Bio.PDB import PDBParser
import numpy as np

# Define the two directories
folder1 = r"/home/nathan/Alphafold-pLDDT-Analysis/AF Structures/E.Coli/AF 2"
folder2 = r"/home/nathan/Alphafold-pLDDT-Analysis/AF Structures/E.Coli/AF 3"
output_folder = r"/home/nathan/Alphafold-pLDDT-Analysis/AF2_AF3_Comparison/E.Coli"  # Output directory for graphs

# Function to extract relevant part of filename (assuming the important string is 6-10 characters long)
def extract_relevant_string(filename):
    return filename[6:10].lower()  # Lowercase for case insensitivity

# Function to load PLDDT values from a PDB file
def load_plddt_values_from_pdb(filepath):
    p = PDBParser()
    structure = p.get_structure('PDB_structure', filepath)

    # Assuming PLDDT values are stored in the B-factor field of the PDB file
    plddt_values = []
    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    plddt_values.append(atom.bfactor)  # B-factor (PLDDT score)

    return plddt_values

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Get list of files in both directories
files1 = os.listdir(folder1)
files2 = os.listdir(folder2)

# Create a dictionary to store PLDDT values for comparison
plddt_data = {}

# Compare files between the two directories based on the relevant string in filenames
for file1 in files1:
    relevant_str1 = extract_relevant_string(file1)
    for file2 in files2:
        relevant_str2 = extract_relevant_string(file2)
        if relevant_str1 == relevant_str2:
            # Load PLDDT values for both files
            filepath1 = os.path.join(folder1, file1)
            filepath2 = os.path.join(folder2, file2)
            try:
                plddt1 = load_plddt_values_from_pdb(filepath1)
                plddt2 = load_plddt_values_from_pdb(filepath2)

                # Store the average PLDDT values for direct comparison
                avg_plddt1 = sum(plddt1) / len(plddt1) if len(plddt1) > 0 else 0
                avg_plddt2 = sum(plddt2) / len(plddt2) if len(plddt2) > 0 else 0
                plddt_data[relevant_str1] = (avg_plddt1, avg_plddt2)
            except Exception as e:
                print(f"Error processing files {file1} and {file2}: {e}")
            break  # Stop after finding the match

# Limit to 40 comparisons (80 bars total: 40 AF 3 + 40 AF 2)
if len(plddt_data) > 40:
    plddt_data = dict(list(plddt_data.items())[:40])

# Prepare data for overall comparison
af3_total = []
af2_total = []

for avg_plddt1, avg_plddt2 in plddt_data.values():
    af3_total.append(avg_plddt1)
    af2_total.append(avg_plddt2)

# Calculate overall averages
af3_avg = sum(af3_total) / len(af3_total) if len(af3_total) > 0 else 0
af2_avg = sum(af2_total) / len(af2_total) if len(af2_total) > 0 else 0

# Create the figure for the comparison bar graph (2 bars: AF3 and AF2)
plt.figure(figsize=(3, 4))  # Set figure size

# Bar graph data
labels = ['AF 3 Prediction', 'AF 2 Prediction']
avg_values = [af3_avg, af2_avg]

# Plot bar graph
plt.bar(labels, avg_values, color=['blue', 'orange'], edgecolor='black', alpha = 0.5)

# Set labels and title
plt.title('Average pLDDT (E.coli Sample)')
plt.ylabel('Average PLDDT Value')

# Save the plot to the output folder
output_path = os.path.join(output_folder, 'Ecoli_comparison_average_plddt.png')
plt.savefig(output_path)
plt.close()  # Close the plot to avoid displaying it interactively

# %%
import os
import matplotlib.pyplot as plt
from Bio.PDB import PDBParser
import numpy as np

# Define directories
folder1 = r"/home/nathan/Alphafold-pLDDT-Analysis/AF Structures/E.Coli/AF 2"
folder2 = r"/home/nathan/Alphafold-pLDDT-Analysis/AF Structures/E.Coli/AF 3"
output_folder = r"/home/nathan/Alphafold-pLDDT-Analysis/AF2_AF3_Comparison/E.Coli"  # Output directory for graphs

# Extract relevant string (protein ID)
def extract_relevant_string(filename):
    return filename.split('.')[0].lower()  # Extract portion before `.pdb`

# Load PLDDT values
def load_plddt_values_from_pdb(filepath):
    p = PDBParser(QUIET=True)
    structure = p.get_structure('PDB_structure', filepath)
    plddt_values = []
    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    plddt_values.append(atom.bfactor)
    return plddt_values

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# List files in folders
files1 = os.listdir(folder1)
files2 = os.listdir(folder2)

# Debugging: Check files and identifiers
print("Files in Folder1:", files1)
print("Files in Folder2:", files2)

# Collect PLDDT data
plddt_data = {}

for file1 in files1:
    id1 = extract_relevant_string(file1)
    for file2 in files2:
        id2 = extract_relevant_string(file2)
        print(f"Matching {file1} ({id1}) with {file2} ({id2})")  # Debug matching
        if id1 == id2:
            try:
                plddt1 = load_plddt_values_from_pdb(os.path.join(folder1, file1))
                plddt2 = load_plddt_values_from_pdb(os.path.join(folder2, file2))
                avg_plddt1 = sum(plddt1) / len(plddt1) if plddt1 else 0
                avg_plddt2 = sum(plddt2) / len(plddt2) if plddt2 else 0
                plddt_data[id1] = (avg_plddt1, avg_plddt2)
            except Exception as e:
                print(f"Error processing {file1} and {file2}: {e}")
            break

# Debugging: Print collected data
print("PLDDT Data:", plddt_data)

# Limit to 40 comparisons
if len(plddt_data) > 40:
    plddt_data = dict(list(plddt_data.items())[:40])

if not plddt_data:
    print("No matching data found. Exiting.")
    exit()

# Prepare for plotting
proteins = list(plddt_data.keys())
af2_values = [x[0] for x in plddt_data.values()]
af3_values = [x[1] for x in plddt_data.values()]

# Plot grouped bar chart
bar_width = 0.35
index = np.arange(len(proteins))

plt.figure(figsize=(12, 4))
plt.bar(index, af2_values, bar_width, label='AF2', color='orange', edgecolor='black', alpha = 0.5)
plt.bar(index + bar_width, af3_values, bar_width, label='AF3', color='blue', edgecolor='black', alpha = 0.5)

# Add labels and title
plt.xlabel('Protein')
plt.ylabel('Average PLDDT Value')
plt.title('Average PLDDT Protein E.coli Sample Set by Alphafold Model')
plt.xticks(index + bar_width / 2, proteins, rotation=90)
plt.legend()

# Save and display
plt.tight_layout()
output_path = os.path.join(output_folder, 'PLDDT_Comparison_40_Proteins.png')
plt.savefig(output_path)
plt.show()
# Out:
# Files in Folder1: ['P0AE30.pdb', 'P39196.pdb', 'P27242.pdb', 'P76046.pdb', 'P33221.pdb', 'P32056.pdb', 'P0AC62.pdb', 'P77736.pdb', 'P38135.pdb', 'P0AGA6.pdb', 'P0A8X4.pdb', 'P75747.pdb', 'P07004.pdb', 'P64610.pdb', 'P46889.pdb', 'P03024.pdb', 'P28303.pdb', 'P24215.pdb', 'P0ACC3.pdb', 'P0AA10.pdb', 'P25552.pdb', 'P31663.pdb', 'P19767.pdb', 'P0A6W9.pdb', 'P0A8M6.pdb', 'P08191.pdb', 'P04993.pdb', 'P23842.pdb', 'P0AD19.pdb', 'P31224.pdb', 'P09557.pdb', 'P33234.pdb', 'P0AC38.pdb', 'P75791.pdb', 'P00960.pdb', 'P0A9I5.pdb', 'P0AFG0.pdb', 'P33368.pdb', 'P37349.pdb', 'P09373.pdb']
# Files in Folder2: ['p31224.pdb', 'p03024.pdb', 'p0a6w9.pdb', 'p37349.pdb', 'p33234.pdb', 'p0acc3.pdb', 'p25552.pdb', 'p0a8m6.pdb', 'p76046.pdb', 'p64610.pdb', 'p33221.pdb', 'p07004.pdb', 'p75747.pdb', 'p0aga6.pdb', 'p19767.pdb', 'p31663.pdb', 'p0a9i5.pdb', 'p08191.pdb', 'p0ac62.pdb', 'p0aa10.pdb', 'p0ae30.pdb', 'p09373.pdb', 'p75791.pdb', 'p23842.pdb', 'p24215.pdb', 'p0ad19.pdb', 'p28303.pdb', 'p0a8x4.pdb', 'p00960.pdb', 'p38135.pdb', 'p04993.pdb', 'p32056.pdb', 'p39196.pdb', 'p46889.pdb', 'p09557.pdb', 'p27242.pdb', 'p0afg0.pdb', 'p77736.pdb', 'p0ac38.pdb', 'p33368.pdb']
# Matching P0AE30.pdb (p0ae30) with p31224.pdb (p31224)
# Matching P0AE30.pdb (p0ae30) with p03024.pdb (p03024)
# Matching P0AE30.pdb (p0ae30) with p0a6w9.pdb (p0a6w9)
# Matching P0AE30.pdb (p0ae30) with p37349.pdb (p37349)
# Matching P0AE30.pdb (p0ae30) with p33234.pdb (p33234)
# Matching P0AE30.pdb (p0ae30) with p0acc3.pdb (p0acc3)
# Matching P0AE30.pdb (p0ae30) with p25552.pdb (p25552)
# Matching P0AE30.pdb (p0ae30) with p0a8m6.pdb (p0a8m6)
# Matching P0AE30.pdb (p0ae30) with p76046.pdb (p76046)
# Matching P0AE30.pdb (p0ae30) with p64610.pdb (p64610)
# Matching P0AE30.pdb (p0ae30) with p33221.pdb (p33221)
# Matching P0AE30.pdb (p0ae30) with p07004.pdb (p07004)
# Matching P0AE30.pdb (p0ae30) with p75747.pdb (p75747)
# Matching P0AE30.pdb (p0ae30) with p0aga6.pdb (p0aga6)
# Matching P0AE30.pdb (p0ae30) with p19767.pdb (p19767)
# Matching P0AE30.pdb (p0ae30) with p31663.pdb (p31663)
# Matching P0AE30.pdb (p0ae30) with p0a9i5.pdb (p0a9i5)
# Matching P0AE30.pdb (p0ae30) with p08191.pdb (p08191)
# Matching P0AE30.pdb (p0ae30) with p0ac62.pdb (p0ac62)
# Matching P0AE30.pdb (p0ae30) with p0aa10.pdb (p0aa10)
# Matching P0AE30.pdb (p0ae30) with p0ae30.pdb (p0ae30)
# Matching P39196.pdb (p39196) with p31224.pdb (p31224)
# Matching P39196.pdb (p39196) with p03024.pdb (p03024)
# Matching P39196.pdb (p39196) with p0a6w9.pdb (p0a6w9)
# Matching P39196.pdb (p39196) with p37349.pdb (p37349)
# Matching P39196.pdb (p39196) with p33234.pdb (p33234)
# Matching P39196.pdb (p39196) with p0acc3.pdb (p0acc3)
# Matching P39196.pdb (p39196) with p25552.pdb (p25552)
# Matching P39196.pdb (p39196) with p0a8m6.pdb (p0a8m6)
# Matching P39196.pdb (p39196) with p76046.pdb (p76046)
# Matching P39196.pdb (p39196) with p64610.pdb (p64610)
# Matching P39196.pdb (p39196) with p33221.pdb (p33221)
# Matching P39196.pdb (p39196) with p07004.pdb (p07004)
# Matching P39196.pdb (p39196) with p75747.pdb (p75747)
# Matching P39196.pdb (p39196) with p0aga6.pdb (p0aga6)
# Matching P39196.pdb (p39196) with p19767.pdb (p19767)
# Matching P39196.pdb (p39196) with p31663.pdb (p31663)
# Matching P39196.pdb (p39196) with p0a9i5.pdb (p0a9i5)
# Matching P39196.pdb (p39196) with p08191.pdb (p08191)
# Matching P39196.pdb (p39196) with p0ac62.pdb (p0ac62)
# Matching P39196.pdb (p39196) with p0aa10.pdb (p0aa10)
# Matching P39196.pdb (p39196) with p0ae30.pdb (p0ae30)
# Matching P39196.pdb (p39196) with p09373.pdb (p09373)
# Matching P39196.pdb (p39196) with p75791.pdb (p75791)
# Matching P39196.pdb (p39196) with p23842.pdb (p23842)
# Matching P39196.pdb (p39196) with p24215.pdb (p24215)
# Matching P39196.pdb (p39196) with p0ad19.pdb (p0ad19)
# Matching P39196.pdb (p39196) with p28303.pdb (p28303)
# Matching P39196.pdb (p39196) with p0a8x4.pdb (p0a8x4)
# Matching P39196.pdb (p39196) with p00960.pdb (p00960)
# Matching P39196.pdb (p39196) with p38135.pdb (p38135)
# Matching P39196.pdb (p39196) with p04993.pdb (p04993)
# Matching P39196.pdb (p39196) with p32056.pdb (p32056)
# Matching P39196.pdb (p39196) with p39196.pdb (p39196)
# Matching P27242.pdb (p27242) with p31224.pdb (p31224)
# Matching P27242.pdb (p27242) with p03024.pdb (p03024)
# Matching P27242.pdb (p27242) with p0a6w9.pdb (p0a6w9)
# Matching P27242.pdb (p27242) with p37349.pdb (p37349)
# Matching P27242.pdb (p27242) with p33234.pdb (p33234)
# Matching P27242.pdb (p27242) with p0acc3.pdb (p0acc3)
# Matching P27242.pdb (p27242) with p25552.pdb (p25552)
# Matching P27242.pdb (p27242) with p0a8m6.pdb (p0a8m6)
# Matching P27242.pdb (p27242) with p76046.pdb (p76046)
# Matching P27242.pdb (p27242) with p64610.pdb (p64610)
# Matching P27242.pdb (p27242) with p33221.pdb (p33221)
# Matching P27242.pdb (p27242) with p07004.pdb (p07004)
# Matching P27242.pdb (p27242) with p75747.pdb (p75747)
# Matching P27242.pdb (p27242) with p0aga6.pdb (p0aga6)
# Matching P27242.pdb (p27242) with p19767.pdb (p19767)
# Matching P27242.pdb (p27242) with p31663.pdb (p31663)
# Matching P27242.pdb (p27242) with p0a9i5.pdb (p0a9i5)
# Matching P27242.pdb (p27242) with p08191.pdb (p08191)
# Matching P27242.pdb (p27242) with p0ac62.pdb (p0ac62)
# Matching P27242.pdb (p27242) with p0aa10.pdb (p0aa10)
# Matching P27242.pdb (p27242) with p0ae30.pdb (p0ae30)
# Matching P27242.pdb (p27242) with p09373.pdb (p09373)
# Matching P27242.pdb (p27242) with p75791.pdb (p75791)
# Matching P27242.pdb (p27242) with p23842.pdb (p23842)
# Matching P27242.pdb (p27242) with p24215.pdb (p24215)
# Matching P27242.pdb (p27242) with p0ad19.pdb (p0ad19)
# Matching P27242.pdb (p27242) with p28303.pdb (p28303)
# Matching P27242.pdb (p27242) with p0a8x4.pdb (p0a8x4)
# Matching P27242.pdb (p27242) with p00960.pdb (p00960)
# Matching P27242.pdb (p27242) with p38135.pdb (p38135)
# Matching P27242.pdb (p27242) with p04993.pdb (p04993)
# Matching P27242.pdb (p27242) with p32056.pdb (p32056)
# Matching P27242.pdb (p27242) with p39196.pdb (p39196)
# Matching P27242.pdb (p27242) with p46889.pdb (p46889)
# Matching P27242.pdb (p27242) with p09557.pdb (p09557)
# Matching P27242.pdb (p27242) with p27242.pdb (p27242)
# Matching P76046.pdb (p76046) with p31224.pdb (p31224)
# Matching P76046.pdb (p76046) with p03024.pdb (p03024)
# Matching P76046.pdb (p76046) with p0a6w9.pdb (p0a6w9)
# Matching P76046.pdb (p76046) with p37349.pdb (p37349)
# Matching P76046.pdb (p76046) with p33234.pdb (p33234)
# Matching P76046.pdb (p76046) with p0acc3.pdb (p0acc3)
# Matching P76046.pdb (p76046) with p25552.pdb (p25552)
# Matching P76046.pdb (p76046) with p0a8m6.pdb (p0a8m6)
# Matching P76046.pdb (p76046) with p76046.pdb (p76046)
# Matching P33221.pdb (p33221) with p31224.pdb (p31224)
# Matching P33221.pdb (p33221) with p03024.pdb (p03024)
# Matching P33221.pdb (p33221) with p0a6w9.pdb (p0a6w9)
# Matching P33221.pdb (p33221) with p37349.pdb (p37349)
# Matching P33221.pdb (p33221) with p33234.pdb (p33234)
# Matching P33221.pdb (p33221) with p0acc3.pdb (p0acc3)
# Matching P33221.pdb (p33221) with p25552.pdb (p25552)
# Matching P33221.pdb (p33221) with p0a8m6.pdb (p0a8m6)
# Matching P33221.pdb (p33221) with p76046.pdb (p76046)
# Matching P33221.pdb (p33221) with p64610.pdb (p64610)
# Matching P33221.pdb (p33221) with p33221.pdb (p33221)
# Matching P32056.pdb (p32056) with p31224.pdb (p31224)
# Matching P32056.pdb (p32056) with p03024.pdb (p03024)
# Matching P32056.pdb (p32056) with p0a6w9.pdb (p0a6w9)
# Matching P32056.pdb (p32056) with p37349.pdb (p37349)
# Matching P32056.pdb (p32056) with p33234.pdb (p33234)
# Matching P32056.pdb (p32056) with p0acc3.pdb (p0acc3)
# Matching P32056.pdb (p32056) with p25552.pdb (p25552)
# Matching P32056.pdb (p32056) with p0a8m6.pdb (p0a8m6)
# Matching P32056.pdb (p32056) with p76046.pdb (p76046)
# Matching P32056.pdb (p32056) with p64610.pdb (p64610)
# Matching P32056.pdb (p32056) with p33221.pdb (p33221)
# Matching P32056.pdb (p32056) with p07004.pdb (p07004)
# Matching P32056.pdb (p32056) with p75747.pdb (p75747)
# Matching P32056.pdb (p32056) with p0aga6.pdb (p0aga6)
# Matching P32056.pdb (p32056) with p19767.pdb (p19767)
# Matching P32056.pdb (p32056) with p31663.pdb (p31663)
# Matching P32056.pdb (p32056) with p0a9i5.pdb (p0a9i5)
# Matching P32056.pdb (p32056) with p08191.pdb (p08191)
# Matching P32056.pdb (p32056) with p0ac62.pdb (p0ac62)
# Matching P32056.pdb (p32056) with p0aa10.pdb (p0aa10)
# Matching P32056.pdb (p32056) with p0ae30.pdb (p0ae30)
# Matching P32056.pdb (p32056) with p09373.pdb (p09373)
# Matching P32056.pdb (p32056) with p75791.pdb (p75791)
# Matching P32056.pdb (p32056) with p23842.pdb (p23842)
# Matching P32056.pdb (p32056) with p24215.pdb (p24215)
# Matching P32056.pdb (p32056) with p0ad19.pdb (p0ad19)
# Matching P32056.pdb (p32056) with p28303.pdb (p28303)
# Matching P32056.pdb (p32056) with p0a8x4.pdb (p0a8x4)
# Matching P32056.pdb (p32056) with p00960.pdb (p00960)
# Matching P32056.pdb (p32056) with p38135.pdb (p38135)
# Matching P32056.pdb (p32056) with p04993.pdb (p04993)
# Matching P32056.pdb (p32056) with p32056.pdb (p32056)
# Matching P0AC62.pdb (p0ac62) with p31224.pdb (p31224)
# Matching P0AC62.pdb (p0ac62) with p03024.pdb (p03024)
# Matching P0AC62.pdb (p0ac62) with p0a6w9.pdb (p0a6w9)
# Matching P0AC62.pdb (p0ac62) with p37349.pdb (p37349)
# Matching P0AC62.pdb (p0ac62) with p33234.pdb (p33234)
# Matching P0AC62.pdb (p0ac62) with p0acc3.pdb (p0acc3)
# Matching P0AC62.pdb (p0ac62) with p25552.pdb (p25552)
# Matching P0AC62.pdb (p0ac62) with p0a8m6.pdb (p0a8m6)
# Matching P0AC62.pdb (p0ac62) with p76046.pdb (p76046)
# Matching P0AC62.pdb (p0ac62) with p64610.pdb (p64610)
# Matching P0AC62.pdb (p0ac62) with p33221.pdb (p33221)
# Matching P0AC62.pdb (p0ac62) with p07004.pdb (p07004)
# Matching P0AC62.pdb (p0ac62) with p75747.pdb (p75747)
# Matching P0AC62.pdb (p0ac62) with p0aga6.pdb (p0aga6)
# Matching P0AC62.pdb (p0ac62) with p19767.pdb (p19767)
# Matching P0AC62.pdb (p0ac62) with p31663.pdb (p31663)
# Matching P0AC62.pdb (p0ac62) with p0a9i5.pdb (p0a9i5)
# Matching P0AC62.pdb (p0ac62) with p08191.pdb (p08191)
# Matching P0AC62.pdb (p0ac62) with p0ac62.pdb (p0ac62)
# Matching P77736.pdb (p77736) with p31224.pdb (p31224)
# Matching P77736.pdb (p77736) with p03024.pdb (p03024)
# Matching P77736.pdb (p77736) with p0a6w9.pdb (p0a6w9)
# Matching P77736.pdb (p77736) with p37349.pdb (p37349)
# Matching P77736.pdb (p77736) with p33234.pdb (p33234)
# Matching P77736.pdb (p77736) with p0acc3.pdb (p0acc3)
# Matching P77736.pdb (p77736) with p25552.pdb (p25552)
# Matching P77736.pdb (p77736) with p0a8m6.pdb (p0a8m6)
# Matching P77736.pdb (p77736) with p76046.pdb (p76046)
# Matching P77736.pdb (p77736) with p64610.pdb (p64610)
# Matching P77736.pdb (p77736) with p33221.pdb (p33221)
# Matching P77736.pdb (p77736) with p07004.pdb (p07004)
# Matching P77736.pdb (p77736) with p75747.pdb (p75747)
# Matching P77736.pdb (p77736) with p0aga6.pdb (p0aga6)
# Matching P77736.pdb (p77736) with p19767.pdb (p19767)
# Matching P77736.pdb (p77736) with p31663.pdb (p31663)
# Matching P77736.pdb (p77736) with p0a9i5.pdb (p0a9i5)
# Matching P77736.pdb (p77736) with p08191.pdb (p08191)
# Matching P77736.pdb (p77736) with p0ac62.pdb (p0ac62)
# Matching P77736.pdb (p77736) with p0aa10.pdb (p0aa10)
# Matching P77736.pdb (p77736) with p0ae30.pdb (p0ae30)
# Matching P77736.pdb (p77736) with p09373.pdb (p09373)
# Matching P77736.pdb (p77736) with p75791.pdb (p75791)
# Matching P77736.pdb (p77736) with p23842.pdb (p23842)
# Matching P77736.pdb (p77736) with p24215.pdb (p24215)
# Matching P77736.pdb (p77736) with p0ad19.pdb (p0ad19)
# Matching P77736.pdb (p77736) with p28303.pdb (p28303)
# Matching P77736.pdb (p77736) with p0a8x4.pdb (p0a8x4)
# Matching P77736.pdb (p77736) with p00960.pdb (p00960)
# Matching P77736.pdb (p77736) with p38135.pdb (p38135)
# Matching P77736.pdb (p77736) with p04993.pdb (p04993)
# Matching P77736.pdb (p77736) with p32056.pdb (p32056)
# Matching P77736.pdb (p77736) with p39196.pdb (p39196)
# Matching P77736.pdb (p77736) with p46889.pdb (p46889)
# Matching P77736.pdb (p77736) with p09557.pdb (p09557)
# Matching P77736.pdb (p77736) with p27242.pdb (p27242)
# Matching P77736.pdb (p77736) with p0afg0.pdb (p0afg0)
# Matching P77736.pdb (p77736) with p77736.pdb (p77736)
# Matching P38135.pdb (p38135) with p31224.pdb (p31224)
# Matching P38135.pdb (p38135) with p03024.pdb (p03024)
# Matching P38135.pdb (p38135) with p0a6w9.pdb (p0a6w9)
# Matching P38135.pdb (p38135) with p37349.pdb (p37349)
# Matching P38135.pdb (p38135) with p33234.pdb (p33234)
# Matching P38135.pdb (p38135) with p0acc3.pdb (p0acc3)
# Matching P38135.pdb (p38135) with p25552.pdb (p25552)
# Matching P38135.pdb (p38135) with p0a8m6.pdb (p0a8m6)
# Matching P38135.pdb (p38135) with p76046.pdb (p76046)
# Matching P38135.pdb (p38135) with p64610.pdb (p64610)
# Matching P38135.pdb (p38135) with p33221.pdb (p33221)
# Matching P38135.pdb (p38135) with p07004.pdb (p07004)
# Matching P38135.pdb (p38135) with p75747.pdb (p75747)
# Matching P38135.pdb (p38135) with p0aga6.pdb (p0aga6)
# Matching P38135.pdb (p38135) with p19767.pdb (p19767)
# Matching P38135.pdb (p38135) with p31663.pdb (p31663)
# Matching P38135.pdb (p38135) with p0a9i5.pdb (p0a9i5)
# Matching P38135.pdb (p38135) with p08191.pdb (p08191)
# Matching P38135.pdb (p38135) with p0ac62.pdb (p0ac62)
# Matching P38135.pdb (p38135) with p0aa10.pdb (p0aa10)
# Matching P38135.pdb (p38135) with p0ae30.pdb (p0ae30)
# Matching P38135.pdb (p38135) with p09373.pdb (p09373)
# Matching P38135.pdb (p38135) with p75791.pdb (p75791)
# Matching P38135.pdb (p38135) with p23842.pdb (p23842)
# Matching P38135.pdb (p38135) with p24215.pdb (p24215)
# Matching P38135.pdb (p38135) with p0ad19.pdb (p0ad19)
# Matching P38135.pdb (p38135) with p28303.pdb (p28303)
# Matching P38135.pdb (p38135) with p0a8x4.pdb (p0a8x4)
# Matching P38135.pdb (p38135) with p00960.pdb (p00960)
# Matching P38135.pdb (p38135) with p38135.pdb (p38135)
# Matching P0AGA6.pdb (p0aga6) with p31224.pdb (p31224)
# Matching P0AGA6.pdb (p0aga6) with p03024.pdb (p03024)
# Matching P0AGA6.pdb (p0aga6) with p0a6w9.pdb (p0a6w9)
# Matching P0AGA6.pdb (p0aga6) with p37349.pdb (p37349)
# Matching P0AGA6.pdb (p0aga6) with p33234.pdb (p33234)
# Matching P0AGA6.pdb (p0aga6) with p0acc3.pdb (p0acc3)
# Matching P0AGA6.pdb (p0aga6) with p25552.pdb (p25552)
# Matching P0AGA6.pdb (p0aga6) with p0a8m6.pdb (p0a8m6)
# Matching P0AGA6.pdb (p0aga6) with p76046.pdb (p76046)
# Matching P0AGA6.pdb (p0aga6) with p64610.pdb (p64610)
# Matching P0AGA6.pdb (p0aga6) with p33221.pdb (p33221)
# Matching P0AGA6.pdb (p0aga6) with p07004.pdb (p07004)
# Matching P0AGA6.pdb (p0aga6) with p75747.pdb (p75747)
# Matching P0AGA6.pdb (p0aga6) with p0aga6.pdb (p0aga6)
# Matching P0A8X4.pdb (p0a8x4) with p31224.pdb (p31224)
# Matching P0A8X4.pdb (p0a8x4) with p03024.pdb (p03024)
# Matching P0A8X4.pdb (p0a8x4) with p0a6w9.pdb (p0a6w9)
# Matching P0A8X4.pdb (p0a8x4) with p37349.pdb (p37349)
# Matching P0A8X4.pdb (p0a8x4) with p33234.pdb (p33234)
# Matching P0A8X4.pdb (p0a8x4) with p0acc3.pdb (p0acc3)
# Matching P0A8X4.pdb (p0a8x4) with p25552.pdb (p25552)
# Matching P0A8X4.pdb (p0a8x4) with p0a8m6.pdb (p0a8m6)
# Matching P0A8X4.pdb (p0a8x4) with p76046.pdb (p76046)
# Matching P0A8X4.pdb (p0a8x4) with p64610.pdb (p64610)
# Matching P0A8X4.pdb (p0a8x4) with p33221.pdb (p33221)
# Matching P0A8X4.pdb (p0a8x4) with p07004.pdb (p07004)
# Matching P0A8X4.pdb (p0a8x4) with p75747.pdb (p75747)
# Matching P0A8X4.pdb (p0a8x4) with p0aga6.pdb (p0aga6)
# Matching P0A8X4.pdb (p0a8x4) with p19767.pdb (p19767)
# Matching P0A8X4.pdb (p0a8x4) with p31663.pdb (p31663)
# Matching P0A8X4.pdb (p0a8x4) with p0a9i5.pdb (p0a9i5)
# Matching P0A8X4.pdb (p0a8x4) with p08191.pdb (p08191)
# Matching P0A8X4.pdb (p0a8x4) with p0ac62.pdb (p0ac62)
# Matching P0A8X4.pdb (p0a8x4) with p0aa10.pdb (p0aa10)
# Matching P0A8X4.pdb (p0a8x4) with p0ae30.pdb (p0ae30)
# Matching P0A8X4.pdb (p0a8x4) with p09373.pdb (p09373)
# Matching P0A8X4.pdb (p0a8x4) with p75791.pdb (p75791)
# Matching P0A8X4.pdb (p0a8x4) with p23842.pdb (p23842)
# Matching P0A8X4.pdb (p0a8x4) with p24215.pdb (p24215)
# Matching P0A8X4.pdb (p0a8x4) with p0ad19.pdb (p0ad19)
# Matching P0A8X4.pdb (p0a8x4) with p28303.pdb (p28303)
# Matching P0A8X4.pdb (p0a8x4) with p0a8x4.pdb (p0a8x4)
# Matching P75747.pdb (p75747) with p31224.pdb (p31224)
# Matching P75747.pdb (p75747) with p03024.pdb (p03024)
# Matching P75747.pdb (p75747) with p0a6w9.pdb (p0a6w9)
# Matching P75747.pdb (p75747) with p37349.pdb (p37349)
# Matching P75747.pdb (p75747) with p33234.pdb (p33234)
# Matching P75747.pdb (p75747) with p0acc3.pdb (p0acc3)
# Matching P75747.pdb (p75747) with p25552.pdb (p25552)
# Matching P75747.pdb (p75747) with p0a8m6.pdb (p0a8m6)
# Matching P75747.pdb (p75747) with p76046.pdb (p76046)
# Matching P75747.pdb (p75747) with p64610.pdb (p64610)
# Matching P75747.pdb (p75747) with p33221.pdb (p33221)
# Matching P75747.pdb (p75747) with p07004.pdb (p07004)
# Matching P75747.pdb (p75747) with p75747.pdb (p75747)
# Matching P07004.pdb (p07004) with p31224.pdb (p31224)
# Matching P07004.pdb (p07004) with p03024.pdb (p03024)
# Matching P07004.pdb (p07004) with p0a6w9.pdb (p0a6w9)
# Matching P07004.pdb (p07004) with p37349.pdb (p37349)
# Matching P07004.pdb (p07004) with p33234.pdb (p33234)
# Matching P07004.pdb (p07004) with p0acc3.pdb (p0acc3)
# Matching P07004.pdb (p07004) with p25552.pdb (p25552)
# Matching P07004.pdb (p07004) with p0a8m6.pdb (p0a8m6)
# Matching P07004.pdb (p07004) with p76046.pdb (p76046)
# Matching P07004.pdb (p07004) with p64610.pdb (p64610)
# Matching P07004.pdb (p07004) with p33221.pdb (p33221)
# Matching P07004.pdb (p07004) with p07004.pdb (p07004)
# Matching P64610.pdb (p64610) with p31224.pdb (p31224)
# Matching P64610.pdb (p64610) with p03024.pdb (p03024)
# Matching P64610.pdb (p64610) with p0a6w9.pdb (p0a6w9)
# Matching P64610.pdb (p64610) with p37349.pdb (p37349)
# Matching P64610.pdb (p64610) with p33234.pdb (p33234)
# Matching P64610.pdb (p64610) with p0acc3.pdb (p0acc3)
# Matching P64610.pdb (p64610) with p25552.pdb (p25552)
# Matching P64610.pdb (p64610) with p0a8m6.pdb (p0a8m6)
# Matching P64610.pdb (p64610) with p76046.pdb (p76046)
# Matching P64610.pdb (p64610) with p64610.pdb (p64610)
# Matching P46889.pdb (p46889) with p31224.pdb (p31224)
# Matching P46889.pdb (p46889) with p03024.pdb (p03024)
# Matching P46889.pdb (p46889) with p0a6w9.pdb (p0a6w9)
# Matching P46889.pdb (p46889) with p37349.pdb (p37349)
# Matching P46889.pdb (p46889) with p33234.pdb (p33234)
# Matching P46889.pdb (p46889) with p0acc3.pdb (p0acc3)
# Matching P46889.pdb (p46889) with p25552.pdb (p25552)
# Matching P46889.pdb (p46889) with p0a8m6.pdb (p0a8m6)
# Matching P46889.pdb (p46889) with p76046.pdb (p76046)
# Matching P46889.pdb (p46889) with p64610.pdb (p64610)
# Matching P46889.pdb (p46889) with p33221.pdb (p33221)
# Matching P46889.pdb (p46889) with p07004.pdb (p07004)
# Matching P46889.pdb (p46889) with p75747.pdb (p75747)
# Matching P46889.pdb (p46889) with p0aga6.pdb (p0aga6)
# Matching P46889.pdb (p46889) with p19767.pdb (p19767)
# Matching P46889.pdb (p46889) with p31663.pdb (p31663)
# Matching P46889.pdb (p46889) with p0a9i5.pdb (p0a9i5)
# Matching P46889.pdb (p46889) with p08191.pdb (p08191)
# Matching P46889.pdb (p46889) with p0ac62.pdb (p0ac62)
# Matching P46889.pdb (p46889) with p0aa10.pdb (p0aa10)
# Matching P46889.pdb (p46889) with p0ae30.pdb (p0ae30)
# Matching P46889.pdb (p46889) with p09373.pdb (p09373)
# Matching P46889.pdb (p46889) with p75791.pdb (p75791)
# Matching P46889.pdb (p46889) with p23842.pdb (p23842)
# Matching P46889.pdb (p46889) with p24215.pdb (p24215)
# Matching P46889.pdb (p46889) with p0ad19.pdb (p0ad19)
# Matching P46889.pdb (p46889) with p28303.pdb (p28303)
# Matching P46889.pdb (p46889) with p0a8x4.pdb (p0a8x4)
# Matching P46889.pdb (p46889) with p00960.pdb (p00960)
# Matching P46889.pdb (p46889) with p38135.pdb (p38135)
# Matching P46889.pdb (p46889) with p04993.pdb (p04993)
# Matching P46889.pdb (p46889) with p32056.pdb (p32056)
# Matching P46889.pdb (p46889) with p39196.pdb (p39196)
# Matching P46889.pdb (p46889) with p46889.pdb (p46889)
# Matching P03024.pdb (p03024) with p31224.pdb (p31224)
# Matching P03024.pdb (p03024) with p03024.pdb (p03024)
# Matching P28303.pdb (p28303) with p31224.pdb (p31224)
# Matching P28303.pdb (p28303) with p03024.pdb (p03024)
# Matching P28303.pdb (p28303) with p0a6w9.pdb (p0a6w9)
# Matching P28303.pdb (p28303) with p37349.pdb (p37349)
# Matching P28303.pdb (p28303) with p33234.pdb (p33234)
# Matching P28303.pdb (p28303) with p0acc3.pdb (p0acc3)
# Matching P28303.pdb (p28303) with p25552.pdb (p25552)
# Matching P28303.pdb (p28303) with p0a8m6.pdb (p0a8m6)
# Matching P28303.pdb (p28303) with p76046.pdb (p76046)
# Matching P28303.pdb (p28303) with p64610.pdb (p64610)
# Matching P28303.pdb (p28303) with p33221.pdb (p33221)
# Matching P28303.pdb (p28303) with p07004.pdb (p07004)
# Matching P28303.pdb (p28303) with p75747.pdb (p75747)
# Matching P28303.pdb (p28303) with p0aga6.pdb (p0aga6)
# Matching P28303.pdb (p28303) with p19767.pdb (p19767)
# Matching P28303.pdb (p28303) with p31663.pdb (p31663)
# Matching P28303.pdb (p28303) with p0a9i5.pdb (p0a9i5)
# Matching P28303.pdb (p28303) with p08191.pdb (p08191)
# Matching P28303.pdb (p28303) with p0ac62.pdb (p0ac62)
# Matching P28303.pdb (p28303) with p0aa10.pdb (p0aa10)
# Matching P28303.pdb (p28303) with p0ae30.pdb (p0ae30)
# Matching P28303.pdb (p28303) with p09373.pdb (p09373)
# Matching P28303.pdb (p28303) with p75791.pdb (p75791)
# Matching P28303.pdb (p28303) with p23842.pdb (p23842)
# Matching P28303.pdb (p28303) with p24215.pdb (p24215)
# Matching P28303.pdb (p28303) with p0ad19.pdb (p0ad19)
# Matching P28303.pdb (p28303) with p28303.pdb (p28303)
# Matching P24215.pdb (p24215) with p31224.pdb (p31224)
# Matching P24215.pdb (p24215) with p03024.pdb (p03024)
# Matching P24215.pdb (p24215) with p0a6w9.pdb (p0a6w9)
# Matching P24215.pdb (p24215) with p37349.pdb (p37349)
# Matching P24215.pdb (p24215) with p33234.pdb (p33234)
# Matching P24215.pdb (p24215) with p0acc3.pdb (p0acc3)
# Matching P24215.pdb (p24215) with p25552.pdb (p25552)
# Matching P24215.pdb (p24215) with p0a8m6.pdb (p0a8m6)
# Matching P24215.pdb (p24215) with p76046.pdb (p76046)
# Matching P24215.pdb (p24215) with p64610.pdb (p64610)
# Matching P24215.pdb (p24215) with p33221.pdb (p33221)
# Matching P24215.pdb (p24215) with p07004.pdb (p07004)
# Matching P24215.pdb (p24215) with p75747.pdb (p75747)
# Matching P24215.pdb (p24215) with p0aga6.pdb (p0aga6)
# Matching P24215.pdb (p24215) with p19767.pdb (p19767)
# Matching P24215.pdb (p24215) with p31663.pdb (p31663)
# Matching P24215.pdb (p24215) with p0a9i5.pdb (p0a9i5)
# Matching P24215.pdb (p24215) with p08191.pdb (p08191)
# Matching P24215.pdb (p24215) with p0ac62.pdb (p0ac62)
# Matching P24215.pdb (p24215) with p0aa10.pdb (p0aa10)
# Matching P24215.pdb (p24215) with p0ae30.pdb (p0ae30)
# Matching P24215.pdb (p24215) with p09373.pdb (p09373)
# Matching P24215.pdb (p24215) with p75791.pdb (p75791)
# Matching P24215.pdb (p24215) with p23842.pdb (p23842)
# Matching P24215.pdb (p24215) with p24215.pdb (p24215)
# Matching P0ACC3.pdb (p0acc3) with p31224.pdb (p31224)
# Matching P0ACC3.pdb (p0acc3) with p03024.pdb (p03024)
# Matching P0ACC3.pdb (p0acc3) with p0a6w9.pdb (p0a6w9)
# Matching P0ACC3.pdb (p0acc3) with p37349.pdb (p37349)
# Matching P0ACC3.pdb (p0acc3) with p33234.pdb (p33234)
# Matching P0ACC3.pdb (p0acc3) with p0acc3.pdb (p0acc3)
# Matching P0AA10.pdb (p0aa10) with p31224.pdb (p31224)
# Matching P0AA10.pdb (p0aa10) with p03024.pdb (p03024)
# Matching P0AA10.pdb (p0aa10) with p0a6w9.pdb (p0a6w9)
# Matching P0AA10.pdb (p0aa10) with p37349.pdb (p37349)
# Matching P0AA10.pdb (p0aa10) with p33234.pdb (p33234)
# Matching P0AA10.pdb (p0aa10) with p0acc3.pdb (p0acc3)
# Matching P0AA10.pdb (p0aa10) with p25552.pdb (p25552)
# Matching P0AA10.pdb (p0aa10) with p0a8m6.pdb (p0a8m6)
# Matching P0AA10.pdb (p0aa10) with p76046.pdb (p76046)
# Matching P0AA10.pdb (p0aa10) with p64610.pdb (p64610)
# Matching P0AA10.pdb (p0aa10) with p33221.pdb (p33221)
# Matching P0AA10.pdb (p0aa10) with p07004.pdb (p07004)
# Matching P0AA10.pdb (p0aa10) with p75747.pdb (p75747)
# Matching P0AA10.pdb (p0aa10) with p0aga6.pdb (p0aga6)
# Matching P0AA10.pdb (p0aa10) with p19767.pdb (p19767)
# Matching P0AA10.pdb (p0aa10) with p31663.pdb (p31663)
# Matching P0AA10.pdb (p0aa10) with p0a9i5.pdb (p0a9i5)
# Matching P0AA10.pdb (p0aa10) with p08191.pdb (p08191)
# Matching P0AA10.pdb (p0aa10) with p0ac62.pdb (p0ac62)
# Matching P0AA10.pdb (p0aa10) with p0aa10.pdb (p0aa10)
# Matching P25552.pdb (p25552) with p31224.pdb (p31224)
# Matching P25552.pdb (p25552) with p03024.pdb (p03024)
# Matching P25552.pdb (p25552) with p0a6w9.pdb (p0a6w9)
# Matching P25552.pdb (p25552) with p37349.pdb (p37349)
# Matching P25552.pdb (p25552) with p33234.pdb (p33234)
# Matching P25552.pdb (p25552) with p0acc3.pdb (p0acc3)
# Matching P25552.pdb (p25552) with p25552.pdb (p25552)
# Matching P31663.pdb (p31663) with p31224.pdb (p31224)
# Matching P31663.pdb (p31663) with p03024.pdb (p03024)
# Matching P31663.pdb (p31663) with p0a6w9.pdb (p0a6w9)
# Matching P31663.pdb (p31663) with p37349.pdb (p37349)
# Matching P31663.pdb (p31663) with p33234.pdb (p33234)
# Matching P31663.pdb (p31663) with p0acc3.pdb (p0acc3)
# Matching P31663.pdb (p31663) with p25552.pdb (p25552)
# Matching P31663.pdb (p31663) with p0a8m6.pdb (p0a8m6)
# Matching P31663.pdb (p31663) with p76046.pdb (p76046)
# Matching P31663.pdb (p31663) with p64610.pdb (p64610)
# Matching P31663.pdb (p31663) with p33221.pdb (p33221)
# Matching P31663.pdb (p31663) with p07004.pdb (p07004)
# Matching P31663.pdb (p31663) with p75747.pdb (p75747)
# Matching P31663.pdb (p31663) with p0aga6.pdb (p0aga6)
# Matching P31663.pdb (p31663) with p19767.pdb (p19767)
# Matching P31663.pdb (p31663) with p31663.pdb (p31663)
# Matching P19767.pdb (p19767) with p31224.pdb (p31224)
# Matching P19767.pdb (p19767) with p03024.pdb (p03024)
# Matching P19767.pdb (p19767) with p0a6w9.pdb (p0a6w9)
# Matching P19767.pdb (p19767) with p37349.pdb (p37349)
# Matching P19767.pdb (p19767) with p33234.pdb (p33234)
# Matching P19767.pdb (p19767) with p0acc3.pdb (p0acc3)
# Matching P19767.pdb (p19767) with p25552.pdb (p25552)
# Matching P19767.pdb (p19767) with p0a8m6.pdb (p0a8m6)
# Matching P19767.pdb (p19767) with p76046.pdb (p76046)
# Matching P19767.pdb (p19767) with p64610.pdb (p64610)
# Matching P19767.pdb (p19767) with p33221.pdb (p33221)
# Matching P19767.pdb (p19767) with p07004.pdb (p07004)
# Matching P19767.pdb (p19767) with p75747.pdb (p75747)
# Matching P19767.pdb (p19767) with p0aga6.pdb (p0aga6)
# Matching P19767.pdb (p19767) with p19767.pdb (p19767)
# Matching P0A6W9.pdb (p0a6w9) with p31224.pdb (p31224)
# Matching P0A6W9.pdb (p0a6w9) with p03024.pdb (p03024)
# Matching P0A6W9.pdb (p0a6w9) with p0a6w9.pdb (p0a6w9)
# Matching P0A8M6.pdb (p0a8m6) with p31224.pdb (p31224)
# Matching P0A8M6.pdb (p0a8m6) with p03024.pdb (p03024)
# Matching P0A8M6.pdb (p0a8m6) with p0a6w9.pdb (p0a6w9)
# Matching P0A8M6.pdb (p0a8m6) with p37349.pdb (p37349)
# Matching P0A8M6.pdb (p0a8m6) with p33234.pdb (p33234)
# Matching P0A8M6.pdb (p0a8m6) with p0acc3.pdb (p0acc3)
# Matching P0A8M6.pdb (p0a8m6) with p25552.pdb (p25552)
# Matching P0A8M6.pdb (p0a8m6) with p0a8m6.pdb (p0a8m6)
# Matching P08191.pdb (p08191) with p31224.pdb (p31224)
# Matching P08191.pdb (p08191) with p03024.pdb (p03024)
# Matching P08191.pdb (p08191) with p0a6w9.pdb (p0a6w9)
# Matching P08191.pdb (p08191) with p37349.pdb (p37349)
# Matching P08191.pdb (p08191) with p33234.pdb (p33234)
# Matching P08191.pdb (p08191) with p0acc3.pdb (p0acc3)
# Matching P08191.pdb (p08191) with p25552.pdb (p25552)
# Matching P08191.pdb (p08191) with p0a8m6.pdb (p0a8m6)
# Matching P08191.pdb (p08191) with p76046.pdb (p76046)
# Matching P08191.pdb (p08191) with p64610.pdb (p64610)
# Matching P08191.pdb (p08191) with p33221.pdb (p33221)
# Matching P08191.pdb (p08191) with p07004.pdb (p07004)
# Matching P08191.pdb (p08191) with p75747.pdb (p75747)
# Matching P08191.pdb (p08191) with p0aga6.pdb (p0aga6)
# Matching P08191.pdb (p08191) with p19767.pdb (p19767)
# Matching P08191.pdb (p08191) with p31663.pdb (p31663)
# Matching P08191.pdb (p08191) with p0a9i5.pdb (p0a9i5)
# Matching P08191.pdb (p08191) with p08191.pdb (p08191)
# Matching P04993.pdb (p04993) with p31224.pdb (p31224)
# Matching P04993.pdb (p04993) with p03024.pdb (p03024)
# Matching P04993.pdb (p04993) with p0a6w9.pdb (p0a6w9)
# Matching P04993.pdb (p04993) with p37349.pdb (p37349)
# Matching P04993.pdb (p04993) with p33234.pdb (p33234)
# Matching P04993.pdb (p04993) with p0acc3.pdb (p0acc3)
# Matching P04993.pdb (p04993) with p25552.pdb (p25552)
# Matching P04993.pdb (p04993) with p0a8m6.pdb (p0a8m6)
# Matching P04993.pdb (p04993) with p76046.pdb (p76046)
# Matching P04993.pdb (p04993) with p64610.pdb (p64610)
# Matching P04993.pdb (p04993) with p33221.pdb (p33221)
# Matching P04993.pdb (p04993) with p07004.pdb (p07004)
# Matching P04993.pdb (p04993) with p75747.pdb (p75747)
# Matching P04993.pdb (p04993) with p0aga6.pdb (p0aga6)
# Matching P04993.pdb (p04993) with p19767.pdb (p19767)
# Matching P04993.pdb (p04993) with p31663.pdb (p31663)
# Matching P04993.pdb (p04993) with p0a9i5.pdb (p0a9i5)
# Matching P04993.pdb (p04993) with p08191.pdb (p08191)
# Matching P04993.pdb (p04993) with p0ac62.pdb (p0ac62)
# Matching P04993.pdb (p04993) with p0aa10.pdb (p0aa10)
# Matching P04993.pdb (p04993) with p0ae30.pdb (p0ae30)
# Matching P04993.pdb (p04993) with p09373.pdb (p09373)
# Matching P04993.pdb (p04993) with p75791.pdb (p75791)
# Matching P04993.pdb (p04993) with p23842.pdb (p23842)
# Matching P04993.pdb (p04993) with p24215.pdb (p24215)
# Matching P04993.pdb (p04993) with p0ad19.pdb (p0ad19)
# Matching P04993.pdb (p04993) with p28303.pdb (p28303)
# Matching P04993.pdb (p04993) with p0a8x4.pdb (p0a8x4)
# Matching P04993.pdb (p04993) with p00960.pdb (p00960)
# Matching P04993.pdb (p04993) with p38135.pdb (p38135)
# Matching P04993.pdb (p04993) with p04993.pdb (p04993)
# Matching P23842.pdb (p23842) with p31224.pdb (p31224)
# Matching P23842.pdb (p23842) with p03024.pdb (p03024)
# Matching P23842.pdb (p23842) with p0a6w9.pdb (p0a6w9)
# Matching P23842.pdb (p23842) with p37349.pdb (p37349)
# Matching P23842.pdb (p23842) with p33234.pdb (p33234)
# Matching P23842.pdb (p23842) with p0acc3.pdb (p0acc3)
# Matching P23842.pdb (p23842) with p25552.pdb (p25552)
# Matching P23842.pdb (p23842) with p0a8m6.pdb (p0a8m6)
# Matching P23842.pdb (p23842) with p76046.pdb (p76046)
# Matching P23842.pdb (p23842) with p64610.pdb (p64610)
# Matching P23842.pdb (p23842) with p33221.pdb (p33221)
# Matching P23842.pdb (p23842) with p07004.pdb (p07004)
# Matching P23842.pdb (p23842) with p75747.pdb (p75747)
# Matching P23842.pdb (p23842) with p0aga6.pdb (p0aga6)
# Matching P23842.pdb (p23842) with p19767.pdb (p19767)
# Matching P23842.pdb (p23842) with p31663.pdb (p31663)
# Matching P23842.pdb (p23842) with p0a9i5.pdb (p0a9i5)
# Matching P23842.pdb (p23842) with p08191.pdb (p08191)
# Matching P23842.pdb (p23842) with p0ac62.pdb (p0ac62)
# Matching P23842.pdb (p23842) with p0aa10.pdb (p0aa10)
# Matching P23842.pdb (p23842) with p0ae30.pdb (p0ae30)
# Matching P23842.pdb (p23842) with p09373.pdb (p09373)
# Matching P23842.pdb (p23842) with p75791.pdb (p75791)
# Matching P23842.pdb (p23842) with p23842.pdb (p23842)
# Matching P0AD19.pdb (p0ad19) with p31224.pdb (p31224)
# Matching P0AD19.pdb (p0ad19) with p03024.pdb (p03024)
# Matching P0AD19.pdb (p0ad19) with p0a6w9.pdb (p0a6w9)
# Matching P0AD19.pdb (p0ad19) with p37349.pdb (p37349)
# Matching P0AD19.pdb (p0ad19) with p33234.pdb (p33234)
# Matching P0AD19.pdb (p0ad19) with p0acc3.pdb (p0acc3)
# Matching P0AD19.pdb (p0ad19) with p25552.pdb (p25552)
# Matching P0AD19.pdb (p0ad19) with p0a8m6.pdb (p0a8m6)
# Matching P0AD19.pdb (p0ad19) with p76046.pdb (p76046)
# Matching P0AD19.pdb (p0ad19) with p64610.pdb (p64610)
# Matching P0AD19.pdb (p0ad19) with p33221.pdb (p33221)
# Matching P0AD19.pdb (p0ad19) with p07004.pdb (p07004)
# Matching P0AD19.pdb (p0ad19) with p75747.pdb (p75747)
# Matching P0AD19.pdb (p0ad19) with p0aga6.pdb (p0aga6)
# Matching P0AD19.pdb (p0ad19) with p19767.pdb (p19767)
# Matching P0AD19.pdb (p0ad19) with p31663.pdb (p31663)
# Matching P0AD19.pdb (p0ad19) with p0a9i5.pdb (p0a9i5)
# Matching P0AD19.pdb (p0ad19) with p08191.pdb (p08191)
# Matching P0AD19.pdb (p0ad19) with p0ac62.pdb (p0ac62)
# Matching P0AD19.pdb (p0ad19) with p0aa10.pdb (p0aa10)
# Matching P0AD19.pdb (p0ad19) with p0ae30.pdb (p0ae30)
# Matching P0AD19.pdb (p0ad19) with p09373.pdb (p09373)
# Matching P0AD19.pdb (p0ad19) with p75791.pdb (p75791)
# Matching P0AD19.pdb (p0ad19) with p23842.pdb (p23842)
# Matching P0AD19.pdb (p0ad19) with p24215.pdb (p24215)
# Matching P0AD19.pdb (p0ad19) with p0ad19.pdb (p0ad19)
# Matching P31224.pdb (p31224) with p31224.pdb (p31224)
# Matching P09557.pdb (p09557) with p31224.pdb (p31224)
# Matching P09557.pdb (p09557) with p03024.pdb (p03024)
# Matching P09557.pdb (p09557) with p0a6w9.pdb (p0a6w9)
# Matching P09557.pdb (p09557) with p37349.pdb (p37349)
# Matching P09557.pdb (p09557) with p33234.pdb (p33234)
# Matching P09557.pdb (p09557) with p0acc3.pdb (p0acc3)
# Matching P09557.pdb (p09557) with p25552.pdb (p25552)
# Matching P09557.pdb (p09557) with p0a8m6.pdb (p0a8m6)
# Matching P09557.pdb (p09557) with p76046.pdb (p76046)
# Matching P09557.pdb (p09557) with p64610.pdb (p64610)
# Matching P09557.pdb (p09557) with p33221.pdb (p33221)
# Matching P09557.pdb (p09557) with p07004.pdb (p07004)
# Matching P09557.pdb (p09557) with p75747.pdb (p75747)
# Matching P09557.pdb (p09557) with p0aga6.pdb (p0aga6)
# Matching P09557.pdb (p09557) with p19767.pdb (p19767)
# Matching P09557.pdb (p09557) with p31663.pdb (p31663)
# Matching P09557.pdb (p09557) with p0a9i5.pdb (p0a9i5)
# Matching P09557.pdb (p09557) with p08191.pdb (p08191)
# Matching P09557.pdb (p09557) with p0ac62.pdb (p0ac62)
# Matching P09557.pdb (p09557) with p0aa10.pdb (p0aa10)
# Matching P09557.pdb (p09557) with p0ae30.pdb (p0ae30)
# Matching P09557.pdb (p09557) with p09373.pdb (p09373)
# Matching P09557.pdb (p09557) with p75791.pdb (p75791)
# Matching P09557.pdb (p09557) with p23842.pdb (p23842)
# Matching P09557.pdb (p09557) with p24215.pdb (p24215)
# Matching P09557.pdb (p09557) with p0ad19.pdb (p0ad19)
# Matching P09557.pdb (p09557) with p28303.pdb (p28303)
# Matching P09557.pdb (p09557) with p0a8x4.pdb (p0a8x4)
# Matching P09557.pdb (p09557) with p00960.pdb (p00960)
# Matching P09557.pdb (p09557) with p38135.pdb (p38135)
# Matching P09557.pdb (p09557) with p04993.pdb (p04993)
# Matching P09557.pdb (p09557) with p32056.pdb (p32056)
# Matching P09557.pdb (p09557) with p39196.pdb (p39196)
# Matching P09557.pdb (p09557) with p46889.pdb (p46889)
# Matching P09557.pdb (p09557) with p09557.pdb (p09557)
# Matching P33234.pdb (p33234) with p31224.pdb (p31224)
# Matching P33234.pdb (p33234) with p03024.pdb (p03024)
# Matching P33234.pdb (p33234) with p0a6w9.pdb (p0a6w9)
# Matching P33234.pdb (p33234) with p37349.pdb (p37349)
# Matching P33234.pdb (p33234) with p33234.pdb (p33234)
# Matching P0AC38.pdb (p0ac38) with p31224.pdb (p31224)
# Matching P0AC38.pdb (p0ac38) with p03024.pdb (p03024)
# Matching P0AC38.pdb (p0ac38) with p0a6w9.pdb (p0a6w9)
# Matching P0AC38.pdb (p0ac38) with p37349.pdb (p37349)
# Matching P0AC38.pdb (p0ac38) with p33234.pdb (p33234)
# Matching P0AC38.pdb (p0ac38) with p0acc3.pdb (p0acc3)
# Matching P0AC38.pdb (p0ac38) with p25552.pdb (p25552)
# Matching P0AC38.pdb (p0ac38) with p0a8m6.pdb (p0a8m6)
# Matching P0AC38.pdb (p0ac38) with p76046.pdb (p76046)
# Matching P0AC38.pdb (p0ac38) with p64610.pdb (p64610)
# Matching P0AC38.pdb (p0ac38) with p33221.pdb (p33221)
# Matching P0AC38.pdb (p0ac38) with p07004.pdb (p07004)
# Matching P0AC38.pdb (p0ac38) with p75747.pdb (p75747)
# Matching P0AC38.pdb (p0ac38) with p0aga6.pdb (p0aga6)
# Matching P0AC38.pdb (p0ac38) with p19767.pdb (p19767)
# Matching P0AC38.pdb (p0ac38) with p31663.pdb (p31663)
# Matching P0AC38.pdb (p0ac38) with p0a9i5.pdb (p0a9i5)
# Matching P0AC38.pdb (p0ac38) with p08191.pdb (p08191)
# Matching P0AC38.pdb (p0ac38) with p0ac62.pdb (p0ac62)
# Matching P0AC38.pdb (p0ac38) with p0aa10.pdb (p0aa10)
# Matching P0AC38.pdb (p0ac38) with p0ae30.pdb (p0ae30)
# Matching P0AC38.pdb (p0ac38) with p09373.pdb (p09373)
# Matching P0AC38.pdb (p0ac38) with p75791.pdb (p75791)
# Matching P0AC38.pdb (p0ac38) with p23842.pdb (p23842)
# Matching P0AC38.pdb (p0ac38) with p24215.pdb (p24215)
# Matching P0AC38.pdb (p0ac38) with p0ad19.pdb (p0ad19)
# Matching P0AC38.pdb (p0ac38) with p28303.pdb (p28303)
# Matching P0AC38.pdb (p0ac38) with p0a8x4.pdb (p0a8x4)
# Matching P0AC38.pdb (p0ac38) with p00960.pdb (p00960)
# Matching P0AC38.pdb (p0ac38) with p38135.pdb (p38135)
# Matching P0AC38.pdb (p0ac38) with p04993.pdb (p04993)
# Matching P0AC38.pdb (p0ac38) with p32056.pdb (p32056)
# Matching P0AC38.pdb (p0ac38) with p39196.pdb (p39196)
# Matching P0AC38.pdb (p0ac38) with p46889.pdb (p46889)
# Matching P0AC38.pdb (p0ac38) with p09557.pdb (p09557)
# Matching P0AC38.pdb (p0ac38) with p27242.pdb (p27242)
# Matching P0AC38.pdb (p0ac38) with p0afg0.pdb (p0afg0)
# Matching P0AC38.pdb (p0ac38) with p77736.pdb (p77736)
# Matching P0AC38.pdb (p0ac38) with p0ac38.pdb (p0ac38)
# Matching P75791.pdb (p75791) with p31224.pdb (p31224)
# Matching P75791.pdb (p75791) with p03024.pdb (p03024)
# Matching P75791.pdb (p75791) with p0a6w9.pdb (p0a6w9)
# Matching P75791.pdb (p75791) with p37349.pdb (p37349)
# Matching P75791.pdb (p75791) with p33234.pdb (p33234)
# Matching P75791.pdb (p75791) with p0acc3.pdb (p0acc3)
# Matching P75791.pdb (p75791) with p25552.pdb (p25552)
# Matching P75791.pdb (p75791) with p0a8m6.pdb (p0a8m6)
# Matching P75791.pdb (p75791) with p76046.pdb (p76046)
# Matching P75791.pdb (p75791) with p64610.pdb (p64610)
# Matching P75791.pdb (p75791) with p33221.pdb (p33221)
# Matching P75791.pdb (p75791) with p07004.pdb (p07004)
# Matching P75791.pdb (p75791) with p75747.pdb (p75747)
# Matching P75791.pdb (p75791) with p0aga6.pdb (p0aga6)
# Matching P75791.pdb (p75791) with p19767.pdb (p19767)
# Matching P75791.pdb (p75791) with p31663.pdb (p31663)
# Matching P75791.pdb (p75791) with p0a9i5.pdb (p0a9i5)
# Matching P75791.pdb (p75791) with p08191.pdb (p08191)
# Matching P75791.pdb (p75791) with p0ac62.pdb (p0ac62)
# Matching P75791.pdb (p75791) with p0aa10.pdb (p0aa10)
# Matching P75791.pdb (p75791) with p0ae30.pdb (p0ae30)
# Matching P75791.pdb (p75791) with p09373.pdb (p09373)
# Matching P75791.pdb (p75791) with p75791.pdb (p75791)
# Matching P00960.pdb (p00960) with p31224.pdb (p31224)
# Matching P00960.pdb (p00960) with p03024.pdb (p03024)
# Matching P00960.pdb (p00960) with p0a6w9.pdb (p0a6w9)
# Matching P00960.pdb (p00960) with p37349.pdb (p37349)
# Matching P00960.pdb (p00960) with p33234.pdb (p33234)
# Matching P00960.pdb (p00960) with p0acc3.pdb (p0acc3)
# Matching P00960.pdb (p00960) with p25552.pdb (p25552)
# Matching P00960.pdb (p00960) with p0a8m6.pdb (p0a8m6)
# Matching P00960.pdb (p00960) with p76046.pdb (p76046)
# Matching P00960.pdb (p00960) with p64610.pdb (p64610)
# Matching P00960.pdb (p00960) with p33221.pdb (p33221)
# Matching P00960.pdb (p00960) with p07004.pdb (p07004)
# Matching P00960.pdb (p00960) with p75747.pdb (p75747)
# Matching P00960.pdb (p00960) with p0aga6.pdb (p0aga6)
# Matching P00960.pdb (p00960) with p19767.pdb (p19767)
# Matching P00960.pdb (p00960) with p31663.pdb (p31663)
# Matching P00960.pdb (p00960) with p0a9i5.pdb (p0a9i5)
# Matching P00960.pdb (p00960) with p08191.pdb (p08191)
# Matching P00960.pdb (p00960) with p0ac62.pdb (p0ac62)
# Matching P00960.pdb (p00960) with p0aa10.pdb (p0aa10)
# Matching P00960.pdb (p00960) with p0ae30.pdb (p0ae30)
# Matching P00960.pdb (p00960) with p09373.pdb (p09373)
# Matching P00960.pdb (p00960) with p75791.pdb (p75791)
# Matching P00960.pdb (p00960) with p23842.pdb (p23842)
# Matching P00960.pdb (p00960) with p24215.pdb (p24215)
# Matching P00960.pdb (p00960) with p0ad19.pdb (p0ad19)
# Matching P00960.pdb (p00960) with p28303.pdb (p28303)
# Matching P00960.pdb (p00960) with p0a8x4.pdb (p0a8x4)
# Matching P00960.pdb (p00960) with p00960.pdb (p00960)
# Matching P0A9I5.pdb (p0a9i5) with p31224.pdb (p31224)
# Matching P0A9I5.pdb (p0a9i5) with p03024.pdb (p03024)
# Matching P0A9I5.pdb (p0a9i5) with p0a6w9.pdb (p0a6w9)
# Matching P0A9I5.pdb (p0a9i5) with p37349.pdb (p37349)
# Matching P0A9I5.pdb (p0a9i5) with p33234.pdb (p33234)
# Matching P0A9I5.pdb (p0a9i5) with p0acc3.pdb (p0acc3)
# Matching P0A9I5.pdb (p0a9i5) with p25552.pdb (p25552)
# Matching P0A9I5.pdb (p0a9i5) with p0a8m6.pdb (p0a8m6)
# Matching P0A9I5.pdb (p0a9i5) with p76046.pdb (p76046)
# Matching P0A9I5.pdb (p0a9i5) with p64610.pdb (p64610)
# Matching P0A9I5.pdb (p0a9i5) with p33221.pdb (p33221)
# Matching P0A9I5.pdb (p0a9i5) with p07004.pdb (p07004)
# Matching P0A9I5.pdb (p0a9i5) with p75747.pdb (p75747)
# Matching P0A9I5.pdb (p0a9i5) with p0aga6.pdb (p0aga6)
# Matching P0A9I5.pdb (p0a9i5) with p19767.pdb (p19767)
# Matching P0A9I5.pdb (p0a9i5) with p31663.pdb (p31663)
# Matching P0A9I5.pdb (p0a9i5) with p0a9i5.pdb (p0a9i5)
# Matching P0AFG0.pdb (p0afg0) with p31224.pdb (p31224)
# Matching P0AFG0.pdb (p0afg0) with p03024.pdb (p03024)
# Matching P0AFG0.pdb (p0afg0) with p0a6w9.pdb (p0a6w9)
# Matching P0AFG0.pdb (p0afg0) with p37349.pdb (p37349)
# Matching P0AFG0.pdb (p0afg0) with p33234.pdb (p33234)
# Matching P0AFG0.pdb (p0afg0) with p0acc3.pdb (p0acc3)
# Matching P0AFG0.pdb (p0afg0) with p25552.pdb (p25552)
# Matching P0AFG0.pdb (p0afg0) with p0a8m6.pdb (p0a8m6)
# Matching P0AFG0.pdb (p0afg0) with p76046.pdb (p76046)
# Matching P0AFG0.pdb (p0afg0) with p64610.pdb (p64610)
# Matching P0AFG0.pdb (p0afg0) with p33221.pdb (p33221)
# Matching P0AFG0.pdb (p0afg0) with p07004.pdb (p07004)
# Matching P0AFG0.pdb (p0afg0) with p75747.pdb (p75747)
# Matching P0AFG0.pdb (p0afg0) with p0aga6.pdb (p0aga6)
# Matching P0AFG0.pdb (p0afg0) with p19767.pdb (p19767)
# Matching P0AFG0.pdb (p0afg0) with p31663.pdb (p31663)
# Matching P0AFG0.pdb (p0afg0) with p0a9i5.pdb (p0a9i5)
# Matching P0AFG0.pdb (p0afg0) with p08191.pdb (p08191)
# Matching P0AFG0.pdb (p0afg0) with p0ac62.pdb (p0ac62)
# Matching P0AFG0.pdb (p0afg0) with p0aa10.pdb (p0aa10)
# Matching P0AFG0.pdb (p0afg0) with p0ae30.pdb (p0ae30)
# Matching P0AFG0.pdb (p0afg0) with p09373.pdb (p09373)
# Matching P0AFG0.pdb (p0afg0) with p75791.pdb (p75791)
# Matching P0AFG0.pdb (p0afg0) with p23842.pdb (p23842)
# Matching P0AFG0.pdb (p0afg0) with p24215.pdb (p24215)
# Matching P0AFG0.pdb (p0afg0) with p0ad19.pdb (p0ad19)
# Matching P0AFG0.pdb (p0afg0) with p28303.pdb (p28303)
# Matching P0AFG0.pdb (p0afg0) with p0a8x4.pdb (p0a8x4)
# Matching P0AFG0.pdb (p0afg0) with p00960.pdb (p00960)
# Matching P0AFG0.pdb (p0afg0) with p38135.pdb (p38135)
# Matching P0AFG0.pdb (p0afg0) with p04993.pdb (p04993)
# Matching P0AFG0.pdb (p0afg0) with p32056.pdb (p32056)
# Matching P0AFG0.pdb (p0afg0) with p39196.pdb (p39196)
# Matching P0AFG0.pdb (p0afg0) with p46889.pdb (p46889)
# Matching P0AFG0.pdb (p0afg0) with p09557.pdb (p09557)
# Matching P0AFG0.pdb (p0afg0) with p27242.pdb (p27242)
# Matching P0AFG0.pdb (p0afg0) with p0afg0.pdb (p0afg0)
# Matching P33368.pdb (p33368) with p31224.pdb (p31224)
# Matching P33368.pdb (p33368) with p03024.pdb (p03024)
# Matching P33368.pdb (p33368) with p0a6w9.pdb (p0a6w9)
# Matching P33368.pdb (p33368) with p37349.pdb (p37349)
# Matching P33368.pdb (p33368) with p33234.pdb (p33234)
# Matching P33368.pdb (p33368) with p0acc3.pdb (p0acc3)
# Matching P33368.pdb (p33368) with p25552.pdb (p25552)
# Matching P33368.pdb (p33368) with p0a8m6.pdb (p0a8m6)
# Matching P33368.pdb (p33368) with p76046.pdb (p76046)
# Matching P33368.pdb (p33368) with p64610.pdb (p64610)
# Matching P33368.pdb (p33368) with p33221.pdb (p33221)
# Matching P33368.pdb (p33368) with p07004.pdb (p07004)
# Matching P33368.pdb (p33368) with p75747.pdb (p75747)
# Matching P33368.pdb (p33368) with p0aga6.pdb (p0aga6)
# Matching P33368.pdb (p33368) with p19767.pdb (p19767)
# Matching P33368.pdb (p33368) with p31663.pdb (p31663)
# Matching P33368.pdb (p33368) with p0a9i5.pdb (p0a9i5)
# Matching P33368.pdb (p33368) with p08191.pdb (p08191)
# Matching P33368.pdb (p33368) with p0ac62.pdb (p0ac62)
# Matching P33368.pdb (p33368) with p0aa10.pdb (p0aa10)
# Matching P33368.pdb (p33368) with p0ae30.pdb (p0ae30)
# Matching P33368.pdb (p33368) with p09373.pdb (p09373)
# Matching P33368.pdb (p33368) with p75791.pdb (p75791)
# Matching P33368.pdb (p33368) with p23842.pdb (p23842)
# Matching P33368.pdb (p33368) with p24215.pdb (p24215)
# Matching P33368.pdb (p33368) with p0ad19.pdb (p0ad19)
# Matching P33368.pdb (p33368) with p28303.pdb (p28303)
# Matching P33368.pdb (p33368) with p0a8x4.pdb (p0a8x4)
# Matching P33368.pdb (p33368) with p00960.pdb (p00960)
# Matching P33368.pdb (p33368) with p38135.pdb (p38135)
# Matching P33368.pdb (p33368) with p04993.pdb (p04993)
# Matching P33368.pdb (p33368) with p32056.pdb (p32056)
# Matching P33368.pdb (p33368) with p39196.pdb (p39196)
# Matching P33368.pdb (p33368) with p46889.pdb (p46889)
# Matching P33368.pdb (p33368) with p09557.pdb (p09557)
# Matching P33368.pdb (p33368) with p27242.pdb (p27242)
# Matching P33368.pdb (p33368) with p0afg0.pdb (p0afg0)
# Matching P33368.pdb (p33368) with p77736.pdb (p77736)
# Matching P33368.pdb (p33368) with p0ac38.pdb (p0ac38)
# Matching P33368.pdb (p33368) with p33368.pdb (p33368)
# Matching P37349.pdb (p37349) with p31224.pdb (p31224)
# Matching P37349.pdb (p37349) with p03024.pdb (p03024)
# Matching P37349.pdb (p37349) with p0a6w9.pdb (p0a6w9)
# Matching P37349.pdb (p37349) with p37349.pdb (p37349)
# Matching P09373.pdb (p09373) with p31224.pdb (p31224)
# Matching P09373.pdb (p09373) with p03024.pdb (p03024)
# Matching P09373.pdb (p09373) with p0a6w9.pdb (p0a6w9)
# Matching P09373.pdb (p09373) with p37349.pdb (p37349)
# Matching P09373.pdb (p09373) with p33234.pdb (p33234)
# Matching P09373.pdb (p09373) with p0acc3.pdb (p0acc3)
# Matching P09373.pdb (p09373) with p25552.pdb (p25552)
# Matching P09373.pdb (p09373) with p0a8m6.pdb (p0a8m6)
# Matching P09373.pdb (p09373) with p76046.pdb (p76046)
# Matching P09373.pdb (p09373) with p64610.pdb (p64610)
# Matching P09373.pdb (p09373) with p33221.pdb (p33221)
# Matching P09373.pdb (p09373) with p07004.pdb (p07004)
# Matching P09373.pdb (p09373) with p75747.pdb (p75747)
# Matching P09373.pdb (p09373) with p0aga6.pdb (p0aga6)
# Matching P09373.pdb (p09373) with p19767.pdb (p19767)
# Matching P09373.pdb (p09373) with p31663.pdb (p31663)
# Matching P09373.pdb (p09373) with p0a9i5.pdb (p0a9i5)
# Matching P09373.pdb (p09373) with p08191.pdb (p08191)
# Matching P09373.pdb (p09373) with p0ac62.pdb (p0ac62)
# Matching P09373.pdb (p09373) with p0aa10.pdb (p0aa10)
# Matching P09373.pdb (p09373) with p0ae30.pdb (p0ae30)
# Matching P09373.pdb (p09373) with p09373.pdb (p09373)
# PLDDT Data: {'p0ae30': (93.32916903813387, 88.41424018212871), 'p39196': (92.80713117546773, 85.98616013628623), 'p27242': (92.43022372881319, 86.07012542372877), 'p76046': (89.13970635775863, 85.53300915948245), 'p33221': (96.40921529175024, 95.8366934942993), 'p32056': (96.30908179012316, 93.47371913580233), 'p0ac62': (92.55209702660383, 92.55209702660383), 'p77736': (97.38544378698222, 94.29619329388544), 'p38135': (89.30281079854811, 89.26708938294036), 'p0aga6': (92.2077876712331, 90.89402054794508), 'p0a8x4': (82.8643418013856, 78.11996535796764), 'p75747': (86.72241779497084, 80.18318375241783), 'p07004': (95.86878720000075, 95.1869759999999), 'p64610': (90.35731578947302, 85.0825906432748), 'p46889': (66.45504831851544, 61.14208639350594), 'p03024': (93.77834742505736, 88.69150269023824), 'p28303': (90.53166333238057, 86.46470991711917), 'p24215': (96.6757749603798, 95.8833819334389), 'p0acc3': (76.26841794569077, 82.47043683589142), 'p0aa10': (94.05015057573073, 94.61192205491582), 'p25552': (95.04500648508377, 91.79054215304805), 'p31663': (96.98479693140851, 94.61327166064979), 'p19767': (88.63914368650208, 81.50531204644415), 'p0a6w9': (95.77375609756095, 94.48253170731724), 'p0a8m6': (92.51209172259482, 86.89808724832213), 'p08191': (93.01320576317032, 86.64774876181897), 'p04993': (88.38095511593292, 89.36207828121682), 'p23842': (87.8309981327455, 81.48314547615007), 'p0ad19': (90.16653084982518, 85.99174621653101), 'p31224': (89.4580365639868, 88.45934009516651), 'p09557': (75.34049689440992, 68.6079710144928), 'p33234': (90.95889382716061, 84.92999506172849), 'p0ac38': (97.06254639738002, 94.23442412663756), 'p75791': (96.12854790419222, 94.54274251497006), 'p00960': (96.05758564437237, 95.28851957585645), 'p0a9i5': (81.55429864253382, 87.11079939668174), 'p0afg0': (74.10781163434879, 78.77921052631591), 'p33368': (97.34302485457407, 94.30290322580662), 'p37349': (88.4235781596447, 84.23838691795966), 'p09373': (97.77046030687161, 96.84470647098054)}
